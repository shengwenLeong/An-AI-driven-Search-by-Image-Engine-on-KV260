# %%
import binascii

# %%
input = open('hash_02.txt','r')
list_line = input.readlines()
hash_code = []
for line in list_line:
    list = line.split(' ')
    hash_code.append(list[1][0:12])
print hash_code[0]
# Out:
# 0c0a08080505

# %%
def byte_to_binary(n):
    return ''.join(str((n & (1 << i)) and 1) for i in reversed(range(8)))
def hex_to_binary(h):
    return ''.join(byte_to_binary(ord(b)) for b in binascii.unhexlify(h))

# %%
print hash_code[0]
print hex_to_binary(hash_code[0])
# Out:
# 0c0a08080505
# 000011000000101000001000000010000000010100000101

# %%
print hash_code[3905]
print hex_to_binary(hash_code[3905])
# Out:
# 0c0a08080707
# 000011000000101000001000000010000000011100000111

# %%
hex_to_binary(hash_code[365])
# Out:
# '000010000000011000000110000001010000010100000101'

# %%
for i in hash_code:
    print hex_to_binary(i)
# Out:
# 000011000000101000001000000010000000010100000101
# 000011000000101000001001000010000000100000001000
# 000010010000011100000111000001110000011000000110
# 000010110000010100000100000001000000010000000100
# 000001100000011000000110000001100000011000000101
# 000011100000101000001001000010000000100000000111
# 000001110000011000000110000001100000010100000101
# 000001010000010100000100000001000000010000000011
# 000001100000010100000101000001000000010000000100
# 000010000000100000001000000001110000011000000110
# 000001000000010000000100000001000000010000000011
# 000010100000100100001001000010000000011100000111
# 000010010000100000001000000001010000010100000101
# 000010010000100000001000000010000000011100000111
# 000001100000010100000101000001010000010100000100
# 000001010000010100000101000001010000010000000100
# 000001000000010000000100000001000000001100000011
# 000001010000010000000100000001000000010000000100
# 000001100000010000000100000001000000010000000100
# ...

# %%
out_file = open('bin_hash_code.txt','w')
for i in hash_code:
    out_file.write(hex_to_binary(i))
    out_file.write('\n')
out_file.close()

# %%
input = open('dval.txt','r')
list_line = input.readlines()
hash_code = []
for line in list_line:
    list = line.split(' ')
    hash_code.append(list[1])
print hash_code[0]
# Out:
# 97

# %%
out_file = open('bin_label.txt','w')
for i in hash_code:
    out_file.write(i)
    out_file.write('\n')
out_file.close()

# %%
bin(867514708759216128)
# Out:
# '0b110000001010000010000000100000000101000001010000000000000000'

# %%
print hash_code[0]
print hex_to_binary(hash_code[0])
# Out:
# 0c0a08080505
# 000011000000101000001000000010000000010100000101

# %%
bin(434039933205020672)
# Out:
# '0b11000000110000001010000010100000101000001010000000000000000'

# %%
bin(434041032716648448)
# Out:
# '0b11000000110000001100000010100000101000001010000000000000000'
